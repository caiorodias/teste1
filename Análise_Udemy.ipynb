# %% [markdown]
# <a href="https://colab.research.google.com/github/caiorodias/teste1/blob/main/An%C3%A1lise_Udemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'/content/udemy_output_All_Finance__Accounting_p1_p626.csv')
df.head(3)
# Out:
#         id                                              title  \
# 0   762616  The Complete SQL Bootcamp 2020: Go from Zero t...
# 1   937678  Tableau 2020 A-Z: Hands-On Tableau Training fo...
# 2  1361790             PMP Exam Prep Seminar -  PMBOK Guide 6
#
#                                   url  is_paid  num_subscribers  avg_rating  \
# 0  /course/the-complete-sql-bootcamp/     True           295509     4.66019
# 1                  /course/tableau10/     True           209070     4.58956
# 2         /course/pmp-pmbok6-35-pdus/     True           155282     4.59491
#
#    avg_rating_recent   rating  num_reviews  is_wishlisted  \
# 0            4.67874  4.67874        78006          False
# 1            4.60015  4.60015        54581          False
# 2            4.59326  4.59326        52653          False
#
#    num_published_lectures  num_published_practice_tests               created  \
# 0                      84                             0  2016-02-14T22:57:48Z
# ...

# %%
df.describe()
# Out:
#                  id  num_subscribers    avg_rating  avg_rating_recent  \
# count  1.360800e+04     13608.000000  13608.000000       13608.000000
# mean   1.681721e+06      2847.010435      3.923293           3.912242
# std    9.539271e+05      9437.865634      1.031304           1.039237
# min    2.762000e+03         0.000000      0.000000           0.000000
# 25%    8.580862e+05        62.000000      3.800000           3.787315
# 50%    1.623421e+06       533.000000      4.194440           4.181735
# 75%    2.503720e+06      2279.500000      4.450000           4.452105
# max    3.486006e+06    374836.000000      5.000000           5.000000
#
#              rating   num_reviews  num_published_lectures  \
# count  13608.000000  13608.000000            13608.000000
# mean       3.912242    243.169827               32.224794
# std        1.039237   1580.965895               42.766911
# min        0.000000      0.000000                0.000000
# ...

# %%
df.isnull().sum()
# Out:
# id                                 0
# title                              0
# url                                0
# is_paid                            0
# num_subscribers                    0
# avg_rating                         0
# avg_rating_recent                  0
# rating                             0
# num_reviews                        0
# is_wishlisted                      0
# num_published_lectures             0
# num_published_practice_tests       0
# created                            0
# published_time                     0
# discount_price__amount          1403
# discount_price__currency        1403
# discount_price__price_string    1403
# price_detail__amount             497
# price_detail__currency           497
# price_detail__price_string       497
# dtype: int64

# %%
df.count()
# Out:
# id                              13608
# title                           13608
# url                             13608
# is_paid                         13608
# num_subscribers                 13608
# avg_rating                      13608
# avg_rating_recent               13608
# rating                          13608
# num_reviews                     13608
# is_wishlisted                   13608
# num_published_lectures          13608
# num_published_practice_tests    13608
# created                         13608
# published_time                  13608
# discount_price__amount          12205
# discount_price__currency        12205
# discount_price__price_string    12205
# price_detail__amount            13111
# price_detail__currency          13111
# price_detail__price_string      13111
# dtype: int64

# %%
df.groupby(['is_paid'])['id'].count()
# Out:
# is_paid
# False      496
# True     13112
# Name: id, dtype: int64
